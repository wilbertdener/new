# %%
# Import the modules from skimage
from skimage import data, color
from matplotlib import pyplot as plt
import numpy as np


# Load the rocket image
rocket = imagem3

# Convert the image to grayscale
gray_scaled_rocket = color.rgb2gray(rocket)

# Show the original image
plt.imshow(rocket)

# Show the grayscale image
plt.imshow(gray_scaled_rocket)

# %%
red = imagem3[:,:,0]
green = imagem3[:,:,1]
blue = imagem3[:,:,2]

#plt.imshow(blue,cmap="gray")
vert=np.flipud(imagem3)
plt.imshow(vert)
plt.show()

# %%
# Flip the image vertically
seville_vertical_flip = np.flipud(imagem3)

# Flip the image horizontally
seville_horizontal_flip = np.fliplr(seville_vertical_flip)

# Show the resulting image
plt.imshow(seville_horizontal_flip)

# %%
# Obtain the red channel
red_channel = imagem3[:, :, 0]

# Plot the red histogram with bins in a range of 256
plt.hist(red_channel.ravel(), bins=256)

# Set title and show
plt.title('Red Histogram')
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-b112a3d917a6> in <module>
#       2 binary = imagem3 > thresh
#       3 #plt.imshow(binary)
# ----> 4 binary.show()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'show'

# %%
# Import the otsu threshold function
from skimage.filters import threshold_otsu
import matplotlib.pyplot as plt
from skimage.color import rgb2gray
import cv2
from skimage import data, color

# Make the image grayscale using rgb2gray
rocket2 = data.rocket()
rocket = cv2.imread('imagem.jpg')
rocket = cv2.cvtColor(rocket, cv2.COLOR_BGR2RGB)
#chess_pieces_image_gray = cv2.cvtColor(rocket, cv2.COLOR_BGR2GRAY)
chess_pieces_image_gray = rgb2gray(rocket)

# Obtain the optimal threshold value with otsu
thresh = threshold_otsu(chess_pieces_image_gray)

# Apply thresholding to the image
binary = chess_pieces_image_gray > thresh

# Show the image
#plt.title('Binary image')

#plt.imshow(chess_pieces_image_gray)
#plt.show()
cv2.imshow('Binary image',thresh)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Import the otsu threshold function
from skimage.filters import threshold_otsu
 

# Make the image grayscale using rgb2gray
chess_pieces_image_gray = rgb2gray(chess_pieces_image)

# Obtain the optimal threshold value with otsu
thresh = threshold_otsu(chess_pieces_image_gray)

# Apply thresholding to the image
binary = chess_pieces_image_gray > thresh

# Show the image
show_image(binary, 'Binary image')

# %%
# Import the local threshold function
from skimage.filters import threshold_local

# Set the block size to 35
block_size = 35

# Obtain the optimal local thresholding
local_thresh = threshold_local(page_image, block_size, offset=10)

# Obtain the binary image by applying local thresholding
binary_local = page_image > local_thresh

# Show the binary image
show_image(binary_local, 'Local thresholding')
